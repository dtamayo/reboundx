# %%
import rebound
import reboundx
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import re
import os

# %%
simID=5
import os
times = []
Eerr = []
for filename in os.listdir('data/'):
    if filename.startswith("IC{0}K".format(simID)):
        print(sa.Nblob, filename)
# Out:
# 10000 IC5K2.7796e+01mag7.7946e-01.bin

# %%
sa = rebound.SimulationArchive('data/'+filename)
E0 = sa[0].calculate_energy()
for sim in sa:
    Ef = sim.calculate_energy()
    times.append(sim.t)
    Eerr.append(abs((Ef-E0)/E0))

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.plot(times, Eerr)
ax.set_xscale('log')
ax.set_yscale('log')
